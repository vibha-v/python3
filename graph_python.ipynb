# %% [markdown]
# <a href="https://colab.research.google.com/github/vibha-v/python3/blob/master/graph_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt
x=[1,7,2]
y=[1,7,5]
z=[4,2,3]
plt.plot(x,y)
plt.plot(x,z)
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt
x=[1,7,2]
y=[1,7,5]
z=[4,2,3]
plt.plot(x,y)
plt.plot(x,z)
plt.title("Graph!")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.legend(["x and y","x and z"])
plt.show()
